# %%
##what are the insights find usig Data visualization

# %%
B + breakdown/divide the data

C  = compare thge data

D   = Distribution the data

R = Relationship b/w the data

T  = Trends  
based on past predicting the future sales

# %% [markdown]
# # Types of Data Visulalization¶

# %% [markdown]
# univariate Analysis  == single variables/xolumns
#
# Biivariate Analysis == Two variables/columns
#
# Multivariate Analysis  == Multivariables/columns

# %% [markdown]
# # Numerical :

# %% [markdown]
# Histogram = Find the "distribution" of the data
#
#
# Boxplot  = Breakdown the data
# *To check "outliers"
#
#
#
# Density = To find the  "Distribution" of the data

# %%
x label = x axis

t labe  = y axis

xticks and y ticks  = values represnts

binsize = 

color

legend = indicator

Tittle  = Title of the plot

# %% [markdown]
# # project super_store_EDA

# %% [markdown]
# # importing the libraties

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

# %% [markdown]
# # importing the Dataset

# %%
df = pd.read_excel(r"C:\Users\pc\Downloads\Sample_-_Superstore.xls")

# %%
df
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0          1  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 1          2  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 2          3  CA-2016-138688 2016-06-12 2016-06-16    Second Class
# 3          4  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# 4          5  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# ...      ...             ...        ...        ...             ...
# 9989    9990  CA-2014-110422 2014-01-21 2014-01-23    Second Class
# 9990    9991  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9991    9992  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9992    9993  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9993    9994  CA-2017-119914 2017-05-04 2017-05-09    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# 0       CG-12520       Claire Gute   Consumer  United States        Henderson
# ...

# %%
df.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3       4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4       5  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
df.drop("Row ID",axis=1,inplace=True)

# %%
df.isna().sum()        # herw there is  no null values
# Out:
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# Quantity         0
# Discount         0
# Profit           0
# dtype: int64

# %% [markdown]
# # Data cleaning¶

# %% [markdown]
# Duplicates values

# %%
df.duplicated().sum()
# Out:
# 1

# %%
df = df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.columns
# Out:
# Index(['Order ID', 'Order Date', 'Ship Date', 'Ship Mode', 'Customer ID',
#        'Customer Name', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Product ID', 'Category', 'Sub-Category', 'Product Name',
#        'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %% [markdown]
# # structural errors

# %%
df.head()
# Out:
#          Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City       State  \
# 0      Claire Gute   Consumer  United States        Henderson    Kentucky
# 1      Claire Gute   Consumer  United States        Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  California
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region       Product ID         Category Sub-Category  \
# ...

# %%
numerical = df.select_dtypes(include=["int","float"])
categorical = df.select_dtypes(include="object")

# %% [markdown]
# # Checking the unique value counts

# %%
for i in categorical:
    print("*"*10, i, "*"*10)
    print(categorical[i].agg(['count', 'nunique', 'unique']))
    print('Value Counts: \n', categorical[i].value_counts())
    print()
# Out:
# ********** Order ID **********
# count                                                   9993
# nunique                                                 5009
# unique     [CA-2016-152156, CA-2016-138688, US-2015-10896...
# Name: Order ID, dtype: object
# Value Counts:
#  CA-2017-100111    14
# CA-2017-157987    12
# US-2016-108504    11
# CA-2016-165330    11
# CA-2016-105732    10
#                   ..
# CA-2016-157259     1
# CA-2017-107986     1
# US-2015-112508     1
# US-2016-126844     1
# CA-2017-119914     1
# Name: Order ID, Length: 5009, dtype: int64
#
# ********** Ship Mode **********
# count                                                   9993
# nunique                                                    4
# unique     [Second Class, Standard Class, First Class, Sa...
# Name: Ship Mode, dtype: object
# Value Counts:
#  Standard Class    5967
# Second Class      1945
# First Class       1538
# Same Day           543
# Name: Ship Mode, dtype: int64
#
# ...

# %% [markdown]
# # Checking the statistical measures

# %%
for i in numerical:
    print("*"*10, i, "*"*10)
    print(numerical[i].agg(['min', 'max', 'mean', 'median', 'std']))
    print()
# Out:
# ********** Postal Code **********
# min        1040.000000
# max       99301.000000
# mean      55191.576403
# median    56560.000000
# std       32065.074478
# Name: Postal Code, dtype: float64
#
# ********** Sales **********
# min           0.444000
# max       22638.480000
# mean        229.852846
# median       54.480000
# std         623.276074
# Name: Sales, dtype: float64
#
# ********** Quantity **********
# min        1.000000
# max       14.000000
# mean       3.789753
# median     3.000000
# std        2.225149
# Name: Quantity, dtype: float64
#
# ********** Discount **********
# min       0.000000
# max       0.800000
# mean      0.156188
# median    0.200000
# std       0.206457
# Name: Discount, dtype: float64
#
# ********** Profit **********
# min      -6599.978000
# max       8399.976000
# mean        28.660971
# median       8.671000
# std        234.271476
# Name: Profit, dtype: float64

# %% [markdown]
# # Duplicated values

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Order ID, Order Date, Ship Date, Ship Mode, Customer ID, Customer Name, Segment, Country, City, State, Postal Code, Region, Product ID, Category, Sub-Category, Product Name, Sales, Quantity, Discount, Profit]
# Index: []

# %%
df = df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # Dropping unwanted columns

# %%
df.drop(['Order ID', 'Postal Code'], axis = 1,  inplace = True )

# %% [markdown]
# # Outliers

# %% [markdown]
# # Satistical method

# %%
D = df.select_dtypes(exclude=["object", 'datetime64[ns]'])

# %%
for i in D.columns:
    q1 = D[i].quantile(0.25)
    q3 = D[i].quantile(0.75)
    IQR = q3 - q1
    lower = q1 -(1.5 * IQR)
    upper = q3 +(1.5 * IQR)
    print(f"{i} lower limit is {lower} ")
    print(f'{i} upper limit is {upper} ')
# Out:
# Sales lower limit is -271.71000000000004
# Sales upper limit is 498.93
# Quantity lower limit is -2.5
# Quantity upper limit is 9.5
# Discount lower limit is -0.30000000000000004
# Discount upper limit is 0.5
# Profit lower limit is -39.71849999999999
# Profit upper limit is 70.81349999999999

# %%
df.plot(kind = 'box', subplots = True, layout = (3,2), figsize = (8,6))
plt.show()

# %% [markdown]
# # Univariate Analysis

# %% [markdown]
# # Numerical :

# %% [markdown]
# Histogram =  To Find the "distribution" of the data
#
#
# Boxplot  = Breakdown the data
# *To check "outliers"
#
#
#
# Density = To find the  "Distribution" of the data

# %% [markdown]
# # Numerical - Hist, Box, Density

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
plt.style.use('classic')

# %% [markdown]
# # Histogram

# %% [markdown]
# # To Find the "distribution" of the data

# %%
df['Profit'].plot(kind = 'hist', 
                  figsize = (6,5),
                  color = 'Blue',
                 grid = True,
                 )
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['Discount'].plot(kind = 'hist',
                    color = 'Red',
                    figsize = (6,5),
                    grid = True,
                   )
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['Sales'].plot(kind = 'hist',
                              figsize = (6,5), 
                              color = 'Green',
                              grid = True,
                )
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['Quantity'].plot(kind = 'hist', 
                    figsize = (6,5), 
                    color = 'orange',
                     grid = True,
                   )
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# # Box plot

# %% [markdown]
# # To find the "outliers "

# %%
df['Profit'].plot(kind = 'box')
# Out:
# <Axes: >

# %%
df['Discount'].plot(kind = 'box')
# Out:
# <Axes: >

# %%
df['Sales'].plot(kind = 'box')
# Out:
# <Axes: >

# %%
df['Quantity'].plot(kind = 'box')
# Out:
# <Axes: >

# %% [markdown]
# # Density Plot

# %% [markdown]
# # To Find the "distribution" of the data¶

# %%
df['Profit'].plot(kind = 'kde')
# Out:
# <Axes: ylabel='Density'>

# %%
df['Discount'].plot(kind = 'kde')
# Out:
# <Axes: ylabel='Density'>

# %%
df['Sales'].plot(kind = 'kde')
# Out:
# <Axes: ylabel='Density'>

# %%
df['Quantity'].plot(kind = 'kde')
# Out:
# <Axes: ylabel='Density'>

# %% [markdown]
# # Summary

# %% [markdown]
# * It is not distributed normally.
# * There are outliers in the dataset
# * no density plot is bell shaped

# %% [markdown]
# # Categorical

# %% [markdown]
# # count, barplot, pie plot

# %% [markdown]
# # seaborn

# %% [markdown]
# # The number of occurrence of each category in the categorical variables

# %%
sns.countplot(data = df,x = 'Category' ,
              color = 'teal',
              orient = 'h')
# Out:
# <Axes: xlabel='Category', ylabel='count'>

# %%
sns.countplot(data = df,x = 'Ship Mode' ,
              color = 'violet', 
              orient = 'h')
# Out:
# <Axes: xlabel='Ship Mode', ylabel='count'>

# %% [markdown]
# # Bar plot

# %%
df['Category'].value_counts().plot(kind = 'bar',
                                   title = "Products Category",
                                   color = ['#388E3C', 'teal', '#C8E6C9'],
                                   grid = True,
                                  )
# Out:
# <Axes: title={'center': 'Products Category'}>

# %%
df['Sub-Category'].value_counts().plot(kind = 'barh', 
                                       color = ['blue', 'green'], 
                                       figsize = (15,9))
# Out:
# <Axes: >

# %%
df['Sub-Category'].value_counts().plot(kind = 'bar', 
                                       color = ['blue', 'green'], 
                                       figsize = (15,9))
# Out:
# <Axes: >

# %%
df['Region'].value_counts().plot(kind = 'bar', 
                                 color = [ '#FF7043','#FFA726', '#FFCA28','#FFEE58'])
# Out:
# <Axes: >

# %%
df['State'].value_counts().plot(kind = 'barh',
                                figsize = (9,7),
                                color = ['orange', 'blue'])
# Out:
# <Axes: >

# %% [markdown]
# # Pie Chart

# %%
df['Sub-Category'].value_counts().plot(kind = 'pie', 
                                       autopct = '%1.1f%%', 
                                       figsize = (5,5))
# Out:
# <Axes: ylabel='Sub-Category'>

# %%
(df["Region"].value_counts()/len(df["Region"])*100).plot(kind = "pie",autopct = '%1.1f',legend =True)
# Out:
# <Axes: ylabel='Region'>

# %%
df['Ship Mode'].value_counts().plot(kind = 'pie', 
                                    autopct = '%1.1f%%',)
# Out:
# <Axes: ylabel='Ship Mode'>

# %% [markdown]
# # Bivariate Analysis

# %% [markdown]
# Bivariate Analysis
#
#
#  * Categorical & Categorical
#
#
#        cross tab,count plot,stacked/group bar chart
#
#  * Categorical & Numerical
#
#        bar chart,group by,pivot,line chart
#
#  * Numerical & Numerical
#
#
#        correlation,scatter plot

# %% [markdown]
# # Categorical and Categorical

# %% [markdown]
# # crosstab, count plot, stacked

# %%
pd.crosstab(df['Country'], df['State'])
# Out:
# State          Alabama  Arizona  Arkansas  California  Colorado  Connecticut  \
# Country
# United States       61      224        60        2001       182           82
#
# State          Delaware  District of Columbia  Florida  Georgia  ...  \
# Country                                                          ...
# United States        96                    10      383      184  ...
#
# State          South Dakota  Tennessee  Texas  Utah  Vermont  Virginia  \
# Country
# United States            12        183    985    53       11       224
#
# State          Washington  West Virginia  Wisconsin  Wyoming
# Country
# United States         506              4        110        1
#
# [1 rows x 49 columns]

# %%
pd.crosstab(df['State'], df['Region'])
# Out:
# Region                Central  East  South  West
# State
# Alabama                     0     0     61     0
# Arizona                     0     0      0   224
# Arkansas                    0     0     60     0
# California                  0     0      0  2001
# Colorado                    0     0      0   182
# Connecticut                 0    82      0     0
# Delaware                    0    96      0     0
# District of Columbia        0    10      0     0
# Florida                     0     0    383     0
# Georgia                     0     0    184     0
# Idaho                       0     0      0    21
# Illinois                  492     0      0     0
# Indiana                   149     0      0     0
# Iowa                       30     0      0     0
# Kansas                     24     0      0     0
# Kentucky                    0     0    139     0
# Louisiana                   0     0     42     0
# Maine                       0     8      0     0
# ...

# %%
pd.crosstab(df['Segment'], df['City'])
# Out:
# City         Aberdeen  Abilene  Akron  Albuquerque  Alexandria  Allen  \
# Segment
# Consumer            1        1     13            4           3      4
# Corporate           0        0      6            4           6      0
# Home Office         0        0      2            6           7      0
#
# City         Allentown  Altoona  Amarillo  Anaheim  ...  Wilmington  Wilson  \
# Segment                                             ...
# Consumer             2        0         8       16  ...          24       2
# Corporate            0        2         2       11  ...           9       3
# Home Office          5        0         0        0  ...           3       1
#
# City         Woodbury  Woodland  Woodstock  Woonsocket  Yonkers  York  \
# Segment
# Consumer            0         1          3           1       13     0
# Corporate           3         2          1           3        0     5
# Home Office         0         0          1           0        2     0
#
# ...

# %%
sns.countplot(data = df, x = 'Country', hue = 'State',width=1)
# Out:
# <Axes: xlabel='Country', ylabel='count'>

# %%
sns.countplot(data = df, x = 'Category', hue = 'Sub-Category',width=0.5)
# Out:
# <Axes: xlabel='Category', ylabel='count'>

# %%
sns.countplot(data = df, x = 'Country', hue = 'Region',width=0.6)
# Out:
# <Axes: xlabel='Country', ylabel='count'>

# %%
sns.countplot(data = df, x = 'State', hue = 'Region',width=1)
# Out:
# <Axes: xlabel='State', ylabel='count'>

# %% [markdown]
# # Categorical & Numerical

# %% [markdown]
# # Group By, Pivot, Line char

# %%
df.groupby(by = "State")['Sales'].mean()
# Out:
# State
# Alabama                  319.846557
# Arizona                  157.508933
# Arkansas                 194.635500
# California               228.729451
# Colorado                 176.418231
# Connecticut              163.223866
# Delaware                 285.948635
# District of Columbia     286.502000
# Florida                  233.612815
# Georgia                  266.825217
# Idaho                    208.689810
# Illinois                 162.939230
# Indiana                  359.431946
# Iowa                     152.658667
# Kansas                   121.429583
# Kentucky                 263.250000
# Louisiana                219.453095
# Maine                    158.816250
# Maryland                 225.766886
# Massachusetts            212.106919
# Michigan                 299.096525
# Minnesota                335.541011
# Mississippi              203.232830
# Missouri                 336.441667
# Montana                  372.623467
# Nebraska                 196.445526
# ...

# %%
df.groupby(by = "Country")['Sales'].mean()
# Out:
# Country
# United States    229.852846
# Name: Sales, dtype: float64

# %%
df.groupby(by = "Region")['Sales'].mean()
# Out:
# Region
# Central    215.772661
# East       238.320993
# South      241.803645
# West       226.493233
# Name: Sales, dtype: float64

# %%
df.groupby(by = "Category")['Sales'].max()
# Out:
# Category
# Furniture           4416.174
# Office Supplies     9892.740
# Technology         22638.480
# Name: Sales, dtype: float64

# %% [markdown]
# # Line chart

# %%
plt.style.use('dark_background')

# %%
df['Profit'].plot(kind = 'line')
# Out:
# <Axes: >

# %%
df['Sales'].plot(kind = 'line')
# Out:
# <Axes: >

# %% [markdown]
# # MultiVariate Analysis

# %% [markdown]
# heatmap
#
#
# pairplot

# %% [markdown]
# # Scatter Plot ()

# %% [markdown]
# # To find the relationship/correlation between 2 numerical columns

# %% [markdown]
# # It  is a subjective not a objective we cant measure the values

# %%
df.plot("Sales","Profit",kind = "scatter",figsize = (5,6))
# Out:
# <Axes: xlabel='Sales', ylabel='Profit'>

# %%
df.plot("Sales","Quantity",kind = "scatter",figsize = (6,6))
# Out:
# <Axes: xlabel='Sales', ylabel='Quantity'>

# %% [markdown]
# # Correlation

# %%
df.corr(numeric_only = True)
# Out:
#              Sales  Quantity  Discount    Profit
# Sales     1.000000  0.200808 -0.028197  0.479067
# Quantity  0.200808  1.000000  0.008680  0.066241
# Discount -0.028197  0.008680  1.000000 -0.219481
# Profit    0.479067  0.066241 -0.219481  1.000000

# %% [markdown]
# # heatmap

# %%
sns.heatmap(df.corr(numeric_only=True),annot=True)
# Out:
# <Axes: >

# %% [markdown]
# Correaltion ranges from -0.2 to +1
#
#
#
# >  -0.2 to 0.5 indicates negative correlation
#
# > +0.5 to 0.1 indicates positive correlation

# %% [markdown]
# # Pairplot

# %%
sns.pairplot(df)

# %% [markdown]
# # conclusion

# %% [markdown]
# > california and New Yark has more states
#
#
#
# > officies supplies purchased more sales
#
#
#
#
# > In West region ship mode is standard class in more no.of time and Central region quantity of items purchased is more
#
#
#
# > consumer purchased more things compared to corporate and house office
#
#
#
# > Correlation between Sales and Quantity is zero and Sales and Profit is moderate
#
#
#
# > Correlation Coefficient ranges from -0.2 to 1
